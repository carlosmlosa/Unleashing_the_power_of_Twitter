# %% [markdown]
# # DataFrame Builder
#
# ### Miguel Cozar and Carlos Munoz, OSNA

# %%
import pandas as pd
from TwitterUser import TwitterUser

# %% [markdown]
# #### 1- Clean the ChatGPT text dumped to an excel into a proper csv file

# %%
# Read the raw input
df = pd.read_excel('people.xlsx', header=None)
# Rename the column, perform string transformation to get the names and drop duplicates
df.rename({0: 'people'}, axis = 1, inplace=1)
df.people = df.people.apply(lambda x: x.split('.')[1].strip())
df = df.drop_duplicates()
# Save to a clean csv file
df.to_csv('cleaned_people.csv', index = False, encoding='utf-8-sig')
df.head(5)
# Out:
#            people
# 0       Joe Biden
# 1       Elon Musk
# 2  Greta Thunberg
# 3   Angela Merkel
# 4      Xi Jinping

# %% [markdown]
# #### 2- Search all using twitter API, it is very possible that some accounts are not found or wrongly found, but we are searching for nodes, not accuracy

# %%
# Define a twitter user instance
user = TwitterUser()

# %%
# Search each user on twitter and build a dataframe
user_dictionary = {}
for person in df.people.to_list():
    try:
        user_dictionary[person] = user.search_user(person)
    except:
        user_dictionary[person] = None
user_dictionary
# Out:
# {'Joe Biden': {'id': 939091,
#   'id_str': '939091',
#   'name': 'Joe Biden',
#   'screen_name': 'JoeBiden',
#   'location': 'Washington, DC',
#   'description': 'Husband to @DrBiden, proud father and grandfather. Ready to build back better for all Americans. Official account is @POTUS.',
#   'url': 'https://t.co/UClrPuJpyZ',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/UClrPuJpyZ',
#       'expanded_url': 'http://joebiden.com',
#       'display_url': 'joebiden.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 36894438,
#   'friends_count': 47,
#   'listed_count': 40867,
#   'created_at': 'Sun Mar 11 17:51:24 +0000 2007',
#   'favourites_count': 25,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': True,
#   'statuses_count': 8894,
#   'lang': None,
#   'status': {'created_at': 'Tue Feb 07 21:02:21 +0000 2023',
#    'id': 1623064645891129344,
#    'id_str': '1623064645891129344',
#    'text': 'Proud of what we’re getting done together, @KamalaHarris. https://t.co/QiczoXcBGa',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'KamalaHarris',
#       'name': 'Kamala Harris',
#       'id': 30354991,
#       'id_str': '30354991',
#       'indices': [43, 56]}],
#     'urls': [],
#     'media': [{'id': 1623064560272830476,
#       'id_str': '1623064560272830476',
#       'indices': [58, 81],
#       'media_url': 'http://pbs.twimg.com/media/FoZIrNwXgAAGBiU.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/FoZIrNwXgAAGBiU.jpg',
#       'url': 'https://t.co/QiczoXcBGa',
#       'display_url': 'pic.twitter.com/QiczoXcBGa',
#       'expanded_url': 'https://twitter.com/JoeBiden/status/1623064645891129344/video/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 544, 'h': 680, 'resize': 'fit'},
#        'large': {'w': 1080, 'h': 1350, 'resize': 'fit'},
#        'medium': {'w': 960, 'h': 1200, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1623064560272830476,
#       'id_str': '1623064560272830476',
#       'indices': [58, 81],
#       'media_url': 'http://pbs.twimg.com/media/FoZIrNwXgAAGBiU.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/FoZIrNwXgAAGBiU.jpg',
#       'url': 'https://t.co/QiczoXcBGa',
#       'display_url': 'pic.twitter.com/QiczoXcBGa',
#       'expanded_url': 'https://twitter.com/JoeBiden/status/1623064645891129344/video/1',
#       'type': 'video',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 544, 'h': 680, 'resize': 'fit'},
#        'large': {'w': 1080, 'h': 1350, 'resize': 'fit'},
#        'medium': {'w': 960, 'h': 1200, 'resize': 'fit'}},
#       'video_info': {'aspect_ratio': [4, 5],
#        'duration_millis': 5422,
#        'variants': [{'bitrate': 2176000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/amplify_video/1623064560272830476/vid/720x900/PCpC2ehWwXb6SSJZ.mp4?tag=16'},
#         {'bitrate': 10368000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/amplify_video/1623064560272830476/vid/1080x1350/u2QJ4yXCTb_qc__B.mp4?tag=16'},
#         {'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/amplify_video/1623064560272830476/pl/BaFvBHA55ZgsPyCj.m3u8?tag=16&container=fmp4'},
#         {'bitrate': 950000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/amplify_video/1623064560272830476/vid/480x600/ucOm2UIJgpC5Bcyd.mp4?tag=16'},
#         {'bitrate': 632000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/amplify_video/1623064560272830476/vid/320x400/4_2PcwnrzWQYm1CG.mp4?tag=16'}]},
#       'additional_media_info': {'monetizable': False}}]},
#    'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 545,
#    'favorite_count': 3024,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '565959',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1308769664240160770/AfgzWVE7_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1308769664240160770/AfgzWVE7_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/939091/1626295479',
#   'profile_link_color': '233F94',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'EBEBFF',
#   'profile_text_color': '323232',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  'Elon Musk': {'id': 44196397,
#   'id_str': '44196397',
#   'name': 'Elon Musk',
#   'screen_name': 'elonmusk',
#   'location': '',
#   'description': '',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 128325520,
#   'friends_count': 178,
#   'listed_count': 114176,
#   'created_at': 'Tue Jun 02 20:12:29 +0000 2009',
#   'favourites_count': 17869,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': True,
#   'statuses_count': 22656,
#   'lang': None,
#   'status': {'created_at': 'Tue Feb 07 20:40:01 +0000 2023',
#    'id': 1623059025075261443,
#    'id_str': '1623059025075261443',
#    'text': '@KanekoaTheGreat Wow, Stengel is explicitly saying that GEC is deceiving the American public! That’s what “propagan… https://t.co/QEAU86vK1t',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'KanekoaTheGreat',
#       'name': 'kanekoa.substack.com',
#       'id': 1085225533623783424,
#       'id_str': '1085225533623783424',
#       'indices': [0, 16]}],
#     'urls': [{'url': 'https://t.co/QEAU86vK1t',
#       'expanded_url': 'https://twitter.com/i/web/status/1623059025075261443',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1623044837762273280,
#    'in_reply_to_status_id_str': '1623044837762273280',
#    'in_reply_to_user_id': 1085225533623783424,
#    'in_reply_to_user_id_str': '1085225533623783424',
#    'in_reply_to_screen_name': 'KanekoaTheGreat',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 2590,
#    'favorite_count': 10318,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1590968738358079488/IY9Gx6Ok_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44196397/1576183471',
#   'profile_link_color': '0084B4',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  'Greta Thunberg': {'id': 1006419421244678144,
#   'id_str': '1006419421244678144',
#   'name': 'Greta Thunberg',
#   'screen_name': 'GretaThunberg',
#   'location': 'Sverige',
#   'description': 'Autistic climate justice activist\nBorn at 375 ppm',
#   'url': 'https://t.co/0HwowCDzNy',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/0HwowCDzNy',
#       'expanded_url': 'http://fridaysforfuture.org',
#       'display_url': 'fridaysforfuture.org',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 5848016,
#   'friends_count': 2866,
#   'listed_count': 12455,
#   'created_at': 'Tue Jun 12 06:14:23 +0000 2018',
#   'favourites_count': 17917,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': True,
#   'statuses_count': 11744,
#   'lang': None,
#   'status': {'created_at': 'Sat Feb 04 16:11:08 +0000 2023',
#    'id': 1621904195535208449,
#    'id_str': '1621904195535208449',
#    'text': 'RT @klimatbevakaren: Temperaturavvikelse för Sverige i januari i år. 6-6,5°C varmare än normalt i norr! https://t.co/Y0OMJ3kpHo',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'klimatbevakaren',
#       'name': 'Klimatbevakaren',
#       'id': 1007707906064732160,
#       'id_str': '1007707906064732160',
#       'indices': [3, 19]}],
#     'urls': [],
#     'media': [{'id': 1621794617623453696,
#       'id_str': '1621794617623453696',
#       'indices': [104, 127],
#       'media_url': 'http://pbs.twimg.com/media/FoHFnLIWIAAg2PA.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/FoHFnLIWIAAg2PA.jpg',
#       'url': 'https://t.co/Y0OMJ3kpHo',
#       'display_url': 'pic.twitter.com/Y0OMJ3kpHo',
#       'expanded_url': 'https://twitter.com/klimatbevakaren/status/1621794622325366785/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1024, 'h': 2048, 'resize': 'fit'},
#        'medium': {'w': 600, 'h': 1200, 'resize': 'fit'},
#        'small': {'w': 340, 'h': 680, 'resize': 'fit'}},
#       'source_status_id': 1621794622325366785,
#       'source_status_id_str': '1621794622325366785',
#       'source_user_id': 1007707906064732160,
#       'source_user_id_str': '1007707906064732160'}]},
#    'extended_entities': {'media': [{'id': 1621794617623453696,
#       'id_str': '1621794617623453696',
#       'indices': [104, 127],
#       'media_url': 'http://pbs.twimg.com/media/FoHFnLIWIAAg2PA.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/FoHFnLIWIAAg2PA.jpg',
#       'url': 'https://t.co/Y0OMJ3kpHo',
#       'display_url': 'pic.twitter.com/Y0OMJ3kpHo',
#       'expanded_url': 'https://twitter.com/klimatbevakaren/status/1621794622325366785/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1024, 'h': 2048, 'resize': 'fit'},
#        'medium': {'w': 600, 'h': 1200, 'resize': 'fit'},
#        'small': {'w': 340, 'h': 680, 'resize': 'fit'}},
#       'source_status_id': 1621794622325366785,
#       'source_status_id_str': '1621794622325366785',
#       'source_user_id': 1007707906064732160,
#       'source_user_id_str': '1007707906064732160'}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Feb 04 08:55:44 +0000 2023',
#     'id': 1621794622325366785,
#     'id_str': '1621794622325366785',
#     'text': 'Temperaturavvikelse för Sverige i januari i år. 6-6,5°C varmare än normalt i norr! https://t.co/Y0OMJ3kpHo',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [],
#      'media': [{'id': 1621794617623453696,
#        'id_str': '1621794617623453696',
#        'indices': [83, 106],
#        'media_url': 'http://pbs.twimg.com/media/FoHFnLIWIAAg2PA.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/FoHFnLIWIAAg2PA.jpg',
#        'url': 'https://t.co/Y0OMJ3kpHo',
#        'display_url': 'pic.twitter.com/Y0OMJ3kpHo',
#        'expanded_url': 'https://twitter.com/klimatbevakaren/status/1621794622325366785/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 1024, 'h': 2048, 'resize': 'fit'},
#         'medium': {'w': 600, 'h': 1200, 'resize': 'fit'},
#         'small': {'w': 340, 'h': 680, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1621794617623453696,
#        'id_str': '1621794617623453696',
#        'indices': [83, 106],
#        'media_url': 'http://pbs.twimg.com/media/FoHFnLIWIAAg2PA.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/FoHFnLIWIAAg2PA.jpg',
#        'url': 'https://t.co/Y0OMJ3kpHo',
#        'display_url': 'pic.twitter.com/Y0OMJ3kpHo',
#        'expanded_url': 'https://twitter.com/klimatbevakaren/status/1621794622325366785/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 1024, 'h': 2048, 'resize': 'fit'},
#         'medium': {'w': 600, 'h': 1200, 'resize': 'fit'},
#         'small': {'w': 340, 'h': 680, 'resize': 'fit'}}}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 247,
#     'favorite_count': 702,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'no'},
#    'is_quote_status': False,
#    'retweet_count': 247,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'no'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1459213153301053442/rL5hhpAI_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1459213153301053442/rL5hhpAI_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1006419421244678144/1559499911',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  'Angela Merkel': {'id': 102550061,
#   'id_str': '102550061',
#   'name': 'Plaid Angela Merkel',
#   'screen_name': 'Plaid_Merkel',
#   'location': 'Berlin (not)',
#   'description': "The Plaid Avenger's updates for German Chancellor Angela Merkel (parody account) (FAKE!)",
#   'url': 'http://t.co/Hke3thmRlC',
#   'entities': {'url': {'urls': [{'url': 'http://t.co/Hke3thmRlC',
#       'expanded_url': 'http://www.plaidavenger.com/leaders/profile/angela-merkel/',
#       'display_url': 'plaidavenger.com/leaders/profil…',
#       'indices': [0, 22]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 33770,
#   'friends_count': 308,
#   'listed_count': 105,
#   'created_at': 'Thu Jan 07 02:27:31 +0000 2010',
#   'favourites_count': 128,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 3111,
#   'lang': None,
#   'status': {'created_at': 'Wed Sep 16 01:07:28 +0000 2020',
#    'id': 1306036950068088832,
#    'id_str': '1306036950068088832',
#    'text': 'I will say it loud for those in the back, anti-semitism and racism is wrong and is a disgrace!!! “education and dia… https://t.co/TeoOHl3xgC',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/TeoOHl3xgC',
#       'expanded_url': 'https://twitter.com/i/web/status/1306036950068088832',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 84,
#    'favorite_count': 459,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'E5E817',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/964152269762650112/uwArk_6n_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/964152269762650112/uwArk_6n_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/102550061/1401295736',
#   'profile_link_color': '0AA6AB',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': '010608',
#   'profile_text_color': 'E81725',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  'Xi Jinping': {'id': 1483753685616365571,
#   'id_str': '1483753685616365571',
#   'name': 'Xi Jinping 🇨🇳 ᶠᵃᵏᵉ',
#   'screen_name': 'XoiXiJinping',
#   'location': '',
#   'description': 'Plesidente suplemo de China y plóximamente del Univelso. Pulso botones y suceden cosas. Cuenta oficialmente parodia',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 16086,
#   'friends_count': 185,
#   'listed_count': 21,
#   'created_at': 'Wed Jan 19 10:50:32 +0000 2022',
#   'favourites_count': 25064,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 14455,
#   'lang': None,
#   'status': {'created_at': 'Tue Feb 07 19:49:54 +0000 2023',
#    'id': 1623046414107287576,
#    'id_str': '1623046414107287576',
#    'text': '@DaftHero Es lo que tendría que hacer la plataforma Twitch así como sus patrocinadores',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'DaftHero',
#       'name': 'gazadventures',
#       'id': 165186285,
#       'id_str': '165186285',
#       'indices': [0, 9]}],
#     'urls': []},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1623007813776683021,
#    'in_reply_to_status_id_str': '1623007813776683021',
#    'in_reply_to_user_id': 165186285,
#    'in_reply_to_user_id_str': '165186285',
#    'in_reply_to_screen_name': 'DaftHero',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 43,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'es'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1573495506201886721/yG3xhklx_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1573495506201886721/yG3xhklx_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1483753685616365571/1645921702',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  'Jeff Bezos': {'id': 15506669,
#   'id_str': '15506669',
#   'name': 'Jeff Bezos',
#   'screen_name': 'JeffBezos',
#   'location': '',
#   'description': 'Amazon. Blue Origin. Washington Post. Bezos Earth Fund. Bezos Academy.',
#   'url': 'https://t.co/SLz7tTMkas',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/SLz7tTMkas',
#       'expanded_url': 'https://hoo.be/jeffbezos',
#       'display_url': 'hoo.be/jeffbezos',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 6118040,
#   'friends_count': 173,
#   'listed_count': 11705,
#   'created_at': 'Sun Jul 20 22:38:36 +0000 2008',
#   'favourites_count': 117,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 386,
#   'lang': None,
#   'status': {'created_at': 'Tue Jan 31 16:59:10 +0000 2023',
#    'id': 1620466730572349442,
#    'id_str': '1620466730572349442',
#    'text': 'Episode 3 of Last of Us is unbelievably good story telling. I am in awe of @Nick_Offerman performance. Incredible.',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Nick_Offerman',
#       'name': 'Nick Offerman',
#       'id': 502135911,
#       'id_str': '502135911',
#       'indices': [75, 89]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1268,
#    'favorite_count': 29668,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1591558315254890500/ETIHb4Nl_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1591558315254890500/ETIHb4Nl_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15506669/1448361938',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  'Mark Zuckerberg': {'id': 20749410,
#   'id_str': '20749410',
#   'name': 'Mark Zuckerberg',
#   'screen_name': 'finkd',
#   'location': '',
#   'description': '',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 559955,
#   'friends_count': 763,
#   'listed_count': 5356,
#   'created_at': 'Fri Feb 13 05:09:01 +0000 2009',
#   'favourites_count': 0,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 19,
#   'lang': None,
#   'status': {'created_at': 'Wed Jan 18 18:15:34 +0000 2012',
#    'id': 159700472020733952,
#    'id_str': '159700472020733952',
#    'text': 'Tell your congressmen you want them to be pro-internet. My Facebook post is here: https://t.co/XEmFNxGt',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/XEmFNxGt',
#       'expanded_url': 'https://www.facebook.com/zuck/posts/10100210345757211',
#       'display_url': 'facebook.com/zuck/posts/101…',
#       'indices': [82, 103]}]},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 3412,
#    'favorite_count': 6226,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/77846223/profile_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/77846223/profile_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  'Satya Nadella': {'id': 20571756,
#   'id_str': '20571756',
#   'name': 'Satya Nadella',
#   'screen_name': 'satyanadella',
#   'location': '',
#   'description': 'Chairman and CEO of Microsoft Corporation',
#   'url': 'http://t.co/UMBNtf23la',
#   'entities': {'url': {'urls': [{'url': 'http://t.co/UMBNtf23la',
#       'expanded_url': 'http://www.microsoft.com/ceo',
#       'display_url': 'microsoft.com/ceo',
#       'indices': [0, 22]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 2977079,
#   'friends_count': 279,
#   'listed_count': 9910,
#   'created_at': 'Wed Feb 11 04:45:34 +0000 2009',
#   'favourites_count': 373,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': True,
#   'statuses_count': 1556,
#   'lang': None,
#   'status': {'created_at': 'Tue Feb 07 18:52:13 +0000 2023',
#    'id': 1623031898544152578,
#    'id_str': '1623031898544152578',
#    'text': 'Bing and Edge + AI: a new way to search starts today https://t.co/0y8sw7waNb',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/0y8sw7waNb',
#       'expanded_url': 'https://blogs.microsoft.com/blog/2023/02/07/reinventing-search-with-a-new-ai-powered-microsoft-bing-and-edge-your-copilot-for-the-web/',
#       'display_url': 'blogs.microsoft.com/blog/2023/02/0…',
#       'indices': [53, 76]}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1731,
#    'favorite_count': 7387,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '352726',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme5/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme5/bg.gif',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1221837516816306177/_Ld4un5A_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1221837516816306177/_Ld4un5A_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/20571756/1553288451',
#   'profile_link_color': '80787A',
#   'profile_sidebar_border_color': '829D5E',
#   'profile_sidebar_fill_color': '99CC33',
#   'profile_text_color': '3E4415',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  'Tim Cook': {'id': 1636590253,
#   'id_str': '1636590253',
#   'name': 'Tim Cook',
#   'screen_name': 'tim_cook',
#   'location': 'Cupertino',
#   'description': "Apple CEO \uf8ff Auburn 🏀 🏈 Duke 🏀 National Parks 🏞️ “Life's most persistent and urgent question is, 'What are you doing for others?'” - MLK. he/him",
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 14009621,
#   'friends_count': 70,
#   'listed_count': 24445,
#   'created_at': 'Wed Jul 31 22:41:25 +0000 2013',
#   'favourites_count': 2047,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 1468,
#   'lang': None,
#   'status': {'created_at': 'Mon Feb 06 16:06:46 +0000 2023',
#    'id': 1622627873524965380,
#    'id_str': '1622627873524965380',
#    'text': 'Sending our thoughts and condolences to the people of Turkey, Syria, and anyone affected by the devastating earthqu… https://t.co/lDcSdLoaap',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/lDcSdLoaap',
#       'expanded_url': 'https://twitter.com/i/web/status/1622627873524965380',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 2966,
#    'favorite_count': 34999,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1535420431766671360/Pwq-1eJc_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1535420431766671360/Pwq-1eJc_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1636590253/1535753003',
#   'profile_link_color': '0084B4',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  'Sundar Pichai': {'id': 14130366,
#   'id_str': '14130366',
#   'name': 'Sundar Pichai',
#   'screen_name': 'sundarpichai',
#   'location': '',
#   'description': 'CEO,  Google and Alphabet',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 5148951,
#   'friends_count': 140,
#   'listed_count': 8885,
#   'created_at': 'Wed Mar 12 05:51:53 +0000 2008',
#   'favourites_count': 945,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 1831,
#   'lang': None,
#   'status': {'created_at': 'Mon Feb 06 19:12:47 +0000 2023',
#    'id': 1622674686814601217,
#    'id_str': '1622674686814601217',
#    'text': '5/ Developers can soon try our Generative Language API, initially powered by LaMDA with a range of models to follow… https://t.co/LKgJEBixk7',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/LKgJEBixk7',
#       'expanded_url': 'https://twitter.com/i/web/status/1622674686814601217',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1622674382069059591,
#    'in_reply_to_status_id_str': '1622674382069059591',
#    'in_reply_to_user_id': 14130366,
#    'in_reply_to_user_id_str': '14130366',
#    'in_reply_to_screen_name': 'sundarpichai',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 151,
#    'favorite_count': 1851,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '1A1B1F',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/864282616597405701/M-FEJMZ0_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/864282616597405701/M-FEJMZ0_normal.jpg',
#   'profile_link_color': '2FC2EF',
#   'profile_sidebar_border_color': '181A1E',
#   'profile_sidebar_fill_color': '252429',
#   'profile_text_color': '666666',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  'Dr': {'id': 133361792,
#   'id_str': '133361792',
#   'name': 'Instituto Mora',
#   'screen_name': 'institutomora',
#   'location': 'Ciudad de México',
#   'description': 'El Instituto de Investigaciones Dr. José María Luis Mora es un Centro Público de Investigación  #Conacyt. #CienciasSociales  #Historia',
#   'url': 'https://t.co/XpXEFWE5JB',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/XpXEFWE5JB',
#       'expanded_url': 'http://www.institutomora.edu.mx',
#       'display_url': 'institutomora.edu.mx',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 30585,
#   'friends_count': 941,
#   'listed_count': 326,
#   'created_at': 'Thu Apr 15 15:55:40 +0000 2010',
#   'favourites_count': 14489,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 34276,
#   'lang': None,
#   'status': {'created_at': 'Tue Feb 07 22:01:41 +0000 2023',
#    'id': 1623079578326470656,
#    'id_str': '1623079578326470656',
#    'text': '❗📻Este #miércoles en Ideas y voces seguiremos conversando sobre la relevancia de los gobiernos subnacionales para h… https://t.co/ZA5LVMTi1C',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'miércoles', 'indices': [7, 17]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/ZA5LVMTi1C',
#       'expanded_url': 'https://twitter.com/i/web/status/1623079578326470656',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="https://www.socialgest.net" rel="nofollow">SocialGest</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'es'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '022330',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1566882171347935234/G9_Ieuub_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1566882171347935234/G9_Ieuub_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/133361792/1672675348',
#   'profile_link_color': '1B95E0',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  'Malala Yousafzai': {'id': 937499232,
#   'id_str': '937499232',
#   'name': 'Malala Yousafzai',
#   'screen_name': 'Malala',
#   'location': '',
#   'description': 'Still just a girl who wants to learn. Youngest-ever Nobel laureate, co-founder @malalafund and president of Extracurricular Productions',
#   'url': 'https://t.co/5rZNiuRqIw',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/5rZNiuRqIw',
#       'expanded_url': 'https://variety.com/2022/global/features/malala-yousafzai-apple-tv-berlanti-productions-1235383600/',
#       'display_url': 'variety.com/2022/global/fe…',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 2004122,
#   'friends_count': 656,
#   'listed_count': 3797,
#   'created_at': 'Fri Nov 09 18:34:52 +0000 2012',
#   'favourites_count': 3219,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': True,
#   'statuses_count': 1030,
#   'lang': None,
#   'status': {'created_at': 'Tue Feb 07 02:44:21 +0000 2023',
#    'id': 1622788324430692352,
#    'id_str': '1622788324430692352',
#    'text': 'RT @antonioguterres: We must work harder for peace everywhere.\n\nWe must work harder for the two billion people who live in countries affect…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'antonioguterres',
#       'name': 'António Guterres',
#       'id': 811229675758505984,
#       'id_str': '811229675758505984',
#       'indices': [3, 19]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Mon Feb 06 15:44:24 +0000 2023',
#     'id': 1622622241950248962,
#     'id_str': '1622622241950248962',
#     'text': 'We must work harder for peace everywhere.\n\nWe must work harder for the two billion people who live in countries aff… https://t.co/LfcRVfHugJ',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/LfcRVfHugJ',
#        'expanded_url': 'https://twitter.com/i/web/status/1622622241950248962',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 865,
#     'favorite_count': 3507,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 865,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1542517013477617665/qzGGRNpA_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1542517013477617665/qzGGRNpA_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/937499232/1663604982',
#   'profile_link_color': 'E0005B',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'has_extended_profile': True,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  'Black Lives Matter activists': {'id': 1140747049350193153,
#   'id_str': '1140747049350193153',
#   'name': 'Julian(Black Lives Matter activists) ✊🏿✊🏿',
#   'screen_name': 'Julian05265078',
#   'location': 'London, England',
#   'description': "I'm real name is Junior Reid and my support is Arsenal FC and BLM✊🏿✊🏿",
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 76,
#   'friends_count': 424,
#   'listed_count': 1,
#   'created_at': 'Mon Jun 17 22:24:25 +0000 2019',
#   'favourites_count': 3533,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 3376,
#   'lang': None,
#   'status': {'created_at': 'Fri Jul 16 20:45:50 +0000 2021',
#    'id': 1416137018430660611,
#    'id_str': '1416137018430660611',
#    'text': 'RT @BeckettUnite: If @Keir_Starmer wants to convince many that he has conviction then call out the NHS sell off &amp; say @UKLabour will revers…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'BeckettUnite',
#       'name': 'Howard Beckett',
#       'id': 1088371662108676096,
#       'id_str': '1088371662108676096',
#       'indices': [3, 16]},
#      {'screen_name': 'Keir_Starmer',
#       'name': 'Keir Starmer',
#       'id': 2425571623,
#       'id_str': '2425571623',
#       'indices': [21, 34]},
#      {'screen_name': 'UKLabour',
#       'name': 'The Labour Party',
#       'id': 14291684,
#       'id_str': '14291684',
#       'indices': [122, 131]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Jul 16 19:58:06 +0000 2021',
#     'id': 1416125005453271045,
#     'id_str': '1416125005453271045',
#     'text': 'If @Keir_Starmer wants to convince many that he has conviction then call out the NHS sell off &amp; say @UKLabour will… https://t.co/i0Ql4sdBdv',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'Keir_Starmer',
#        'name': 'Keir Starmer',
#        'id': 2425571623,
#        'id_str': '2425571623',
#        'indices': [3, 16]},
#       {'screen_name': 'UKLabour',
#        'name': 'The Labour Party',
#        'id': 14291684,
#        'id_str': '14291684',
#        'indices': [104, 113]}],
#      'urls': [{'url': 'https://t.co/i0Ql4sdBdv',
#        'expanded_url': 'https://twitter.com/i/web/status/1416125005453271045',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [120, 143]}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1101,
#     'favorite_count': 3183,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1101,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1140747226169430022/I5PtPmaV_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1140747226169430022/I5PtPmaV_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1140747049350193153/1599066779',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  'Jacinda Ardern': {'id': 22959763,
#   'id_str': '22959763',
#   'name': 'Jacinda Ardern',
#   'screen_name': 'jacindaardern',
#   'location': 'Auckland, New Zealand',
#   'description': 'Former Prime Minister of New Zealand. MP for Mt Albert. Authorised by Rob Salmond 160 Willis St, Wellington',
#   'url': 'https://t.co/tInDNWrsGC',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/tInDNWrsGC',
#       'expanded_url': 'http://www.labour.org.nz',
#       'display_url': 'labour.org.nz',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 811787,
#   'friends_count': 3987,
#   'listed_count': 2279,
#   'created_at': 'Thu Mar 05 18:57:11 +0000 2009',
#   'favourites_count': 630,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 6916,
#   'lang': None,
#   'status': {'created_at': 'Tue Aug 02 20:05:35 +0000 2022',
#    'id': 1554559055280029701,
#    'id_str': '1554559055280029701',
#    'text': '@ArchivesNZ Thank you so much to all the team working at @ArchivesNZ for making this happen! It was a really specia… https://t.co/9wAYNTLqlc',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
# ...
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  'Tim Walz': {'id': 85726335,
#   'id_str': '85726335',
#   'name': 'Tim Walz',
#   'screen_name': 'Tim_Walz',
#   'location': 'Minnesota, USA',
#   'description': 'Dad. Uncle. Husband. Teacher. Coach. Army National Guard. Former Member of Congress. Governor of Minnesota. Official Twitter: @GovTimWalz',
#   'url': 'https://t.co/kkrwK8xNDU',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/kkrwK8xNDU',
#       'expanded_url': 'http://www.walzflanagan.org',
#       'display_url': 'walzflanagan.org',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 46371,
#   'friends_count': 1893,
#   'listed_count': 520,
#   'created_at': 'Wed Oct 28 02:36:26 +0000 2009',
#   'favourites_count': 1477,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 3738,
#   'lang': None,
#   'status': {'created_at': 'Fri Jan 13 17:01:55 +0000 2023',
#    'id': 1613944442653900800,
#    'id_str': '1613944442653900800',
#    'text': "RT @MinnesotaDFL: The DFL Party legislative trifecta was sworn in less than two weeks ago, yet they're already delivering for Minnesotans!…",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'MinnesotaDFL',
#       'name': 'Minnesota DFL Party',
#       'id': 15900384,
#       'id_str': '15900384',
#       'indices': [3, 16]}],
#     'urls': []},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Jan 13 15:17:48 +0000 2023',
#     'id': 1613918242879283200,
#     'id_str': '1613918242879283200',
#     'text': "The DFL Party legislative trifecta was sworn in less than two weeks ago, yet they're already delivering for Minneso… https://t.co/e2vo10ZSlI",
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/e2vo10ZSlI',
#        'expanded_url': 'https://twitter.com/i/web/status/1613918242879283200',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1613884316899020800,
#     'quoted_status_id_str': '1613884316899020800',
#     'retweet_count': 18,
#     'favorite_count': 63,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': True,
#    'quoted_status_id': 1613884316899020800,
#    'quoted_status_id_str': '1613884316899020800',
#    'retweet_count': 18,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '151F85',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1036635749687480324/eOFj4dnY_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1036635749687480324/eOFj4dnY_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/85726335/1660141919',
#   'profile_link_color': '3B94D9',
#   'profile_sidebar_border_color': '0A058C',
#   'profile_sidebar_fill_color': 'FFFF14',
#   'profile_text_color': '0B0BA1',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  'Phil Bryant': {'id': 231592153,
#   'id_str': '231592153',
#   'name': 'Phil Bryant',
#   'screen_name': 'PhilBryantMS',
#   'location': 'Mississippi',
#   'description': 'Christian. Husband. Father. Grandfather. Conservative. Outdoorsman. 64th Governor of the great state of Mississippi.',
#   'url': 'https://t.co/SH2WEbrhqX',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/SH2WEbrhqX',
#       'expanded_url': 'http://www.BryantSongySnell.com',
#       'display_url': 'BryantSongySnell.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 85691,
#   'friends_count': 910,
#   'listed_count': 580,
#   'created_at': 'Tue Dec 28 23:30:49 +0000 2010',
#   'favourites_count': 573,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 7152,
#   'lang': None,
#   'status': {'created_at': 'Sat Oct 29 23:23:02 +0000 2022',
#    'id': 1586498877657866240,
#    'id_str': '1586498877657866240',
#    'text': 'Mississippi has lost another Music Legend with the passing of the late great Jerry Lee Lewis. https://t.co/ZO2lOAH0Ic',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1586498771541704705,
#       'id_str': '1586498771541704705',
#       'indices': [94, 117],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1586498771541704705/pu/img/UsqDf0Ch8lTATVbd.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1586498771541704705/pu/img/UsqDf0Ch8lTATVbd.jpg',
#       'url': 'https://t.co/ZO2lOAH0Ic',
#       'display_url': 'pic.twitter.com/ZO2lOAH0Ic',
#       'expanded_url': 'https://twitter.com/PhilBryantMS/status/1586498877657866240/video/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#        'large': {'w': 1280, 'h': 720, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1586498771541704705,
#       'id_str': '1586498771541704705',
#       'indices': [94, 117],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1586498771541704705/pu/img/UsqDf0Ch8lTATVbd.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1586498771541704705/pu/img/UsqDf0Ch8lTATVbd.jpg',
#       'url': 'https://t.co/ZO2lOAH0Ic',
#       'display_url': 'pic.twitter.com/ZO2lOAH0Ic',
#       'expanded_url': 'https://twitter.com/PhilBryantMS/status/1586498877657866240/video/1',
#       'type': 'video',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#        'large': {'w': 1280, 'h': 720, 'resize': 'fit'}},
#       'video_info': {'aspect_ratio': [16, 9],
#        'duration_millis': 44385,
#        'variants': [{'bitrate': 2176000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1586498771541704705/pu/vid/1280x720/NbaZe-IGJwtAeHvp.mp4?tag=12'},
#         {'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1586498771541704705/pu/vid/640x360/RNKXncJ4ZrwlP85w.mp4?tag=12'},
#         {'bitrate': 256000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1586498771541704705/pu/vid/480x270/SSkhs9Zbufuidl6W.mp4?tag=12'},
#         {'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/ext_tw_video/1586498771541704705/pu/pl/HR_bxmO2jzs09ezf.m3u8?tag=12&container=fmp4'}]},
#       'additional_media_info': {'monetizable': False}}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 19,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'BAE1FF',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1000035809498714113/kB_zUSgH_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1000035809498714113/kB_zUSgH_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/231592153/1569257030',
#   'profile_link_color': '2FC2EF',
#   'profile_sidebar_border_color': '181A1E',
#   'profile_sidebar_fill_color': '252429',
#   'profile_text_color': '666666',
#   'profile_use_background_image': False,
#   'has_extended_profile': True,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  'Nathan Deal': {'id': 217416964,
#   'id_str': '217416964',
#   'name': 'Former Gov. Nathan Deal',
#   'screen_name': 'GovernorDeal',
#   'location': '',
#   'description': 'Nathan Deal served as the 82nd Governor of Georgia.',
#   'url': 'https://t.co/877RzfdHxq',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/877RzfdHxq',
#       'expanded_url': 'http://nathandeal.georgia.gov',
#       'display_url': 'nathandeal.georgia.gov',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 136523,
#   'friends_count': 305,
#   'listed_count': 745,
#   'created_at': 'Fri Nov 19 13:36:16 +0000 2010',
#   'favourites_count': 230,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 3122,
#   'lang': None,
#   'status': {'created_at': 'Mon Jan 14 18:45:03 +0000 2019',
#    'id': 1084884114401120258,
#    'id_str': '1084884114401120258',
#    'text': ".@GAFirstLadyDeal and I are so proud of all that's been accomplished during my time in office, as well as all those… https://t.co/Y1mScjI6iz",
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'GAFirstLadyDeal',
#       'name': 'Sandra Deal',
#       'id': 534503883,
#       'id_str': '534503883',
#       'indices': [1, 17]}],
#     'urls': [{'url': 'https://t.co/Y1mScjI6iz',
#       'expanded_url': 'https://twitter.com/i/web/status/1084884114401120258',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1084884113163726848,
#    'in_reply_to_status_id_str': '1084884113163726848',
#    'in_reply_to_user_id': 217416964,
#    'in_reply_to_user_id_str': '217416964',
#    'in_reply_to_screen_name': 'GovernorDeal',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 19,
#    'favorite_count': 193,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '091847',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/829789168633049092/CL_B_uqQ_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/829789168633049092/CL_B_uqQ_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/217416964/1489074996',
#   'profile_link_color': '384D75',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': 'DDFFCC',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  'David Y': {'id': 24342206,
#   'id_str': '24342206',
#   'name': 'Manu Ginobili',
#   'screen_name': 'manuginobili',
#   'location': 'San Antonio / Bahia Blanca',
#   'description': 'Era el 20 de los Spurs y el 5 de Argentina. \nNow Special Advisor to Basketball Operations for the San Antonio Spurs.',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 4800676,
#   'friends_count': 119,
#   'listed_count': 10246,
#   'created_at': 'Sat Mar 14 06:48:43 +0000 2009',
#   'favourites_count': 2091,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 6840,
#   'lang': None,
#   'status': {'created_at': 'Tue Feb 07 15:31:05 +0000 2023',
#    'id': 1622981280827682817,
#    'id_str': '1622981280827682817',
#    'text': '@tomipierucci @dsaezgil Grande Diegooooooooooooo!! Felicitaciones! 🥂',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'tomipierucci',
#       'name': 'Tomi Pierucci 🌎',
#       'id': 204427289,
#       'id_str': '204427289',
#       'indices': [0, 13]},
#      {'screen_name': 'dsaezgil',
#       'name': 'Diego Saez Gil',
#       'id': 87111271,
#       'id_str': '87111271',
#       'indices': [14, 23]}],
#     'urls': []},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1622968746741764096,
#    'in_reply_to_status_id_str': '1622968746741764096',
#    'in_reply_to_user_id': 204427289,
#    'in_reply_to_user_id_str': '204427289',
#    'in_reply_to_screen_name': 'tomipierucci',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 4,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'es'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '9AE4E8',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/913899373490311169/N-NqPVLm_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/913899373490311169/N-NqPVLm_normal.jpg',
#   'profile_link_color': 'B9B9B6',
#   'profile_sidebar_border_color': '0A0B0A',
#   'profile_sidebar_fill_color': '908989',
#   'profile_text_color': '030202',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'regular',
#   'withheld_in_countries': []}}

# %%
# Some example of how it is
user_dictionary['Cristiano Ronaldo']
# Out:
# {'id': 155659213,
#  'id_str': '155659213',
#  'name': 'Cristiano Ronaldo',
#  'screen_name': 'Cristiano',
#  'location': '',
#  'description': 'This Privacy Policy addresses the collection and use of personal information - https://t.co/N9W2J34YdA',
#  'url': 'https://t.co/JlMkKHxKo1',
#  'entities': {'url': {'urls': [{'url': 'https://t.co/JlMkKHxKo1',
#      'expanded_url': 'http://www.facebook.com/cristiano',
#      'display_url': 'facebook.com/cristiano',
#      'indices': [0, 23]}]},
#   'description': {'urls': [{'url': 'https://t.co/N9W2J34YdA',
#      'expanded_url': 'http://www.cristianoronaldo.com/terms',
#      'display_url': 'cristianoronaldo.com/terms',
#      'indices': [79, 102]}]}},
#  'protected': False,
#  'followers_count': 107529005,
#  'friends_count': 65,
#  'listed_count': 85591,
#  'created_at': 'Mon Jun 14 19:09:20 +0000 2010',
#  'favourites_count': 6,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'verified': True,
#  'statuses_count': 3869,
#  'lang': None,
#  'status': {'created_at': 'Fri Feb 03 20:09:40 +0000 2023',
#   'id': 1621601837051691012,
#   'id_str': '1621601837051691012',
#   'text': 'Happy to have scored my first goal in the Saudi league and great effort by whole team to achieve an important draw… https://t.co/V3XpKoNDk6',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/V3XpKoNDk6',
#      'expanded_url': 'https://twitter.com/i/web/status/1621601837051691012',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 22488,
#   'favorite_count': 298727,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': True,
#  'profile_background_color': '080101',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': False,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1594446880498401282/o4L2z8Ay_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1594446880498401282/o4L2z8Ay_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/155659213/1668980773',
#  'profile_link_color': '1643C9',
#  'profile_sidebar_border_color': 'FFFFFF',
#  'profile_sidebar_fill_color': '838387',
#  'profile_text_color': '0D0D0D',
#  'profile_use_background_image': True,
#  'has_extended_profile': False,
#  'default_profile': False,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'regular',
#  'withheld_in_countries': []}

# %%
# Now we get the keys that we want for our final dataset
preferred_keys = ['id', 'name', 'screen_name', 'location', 'followers_count', 'friends_count']

# And we extract them from the dictionary, we will make a simple function to protect from None values
def extract_key(user, key):
    try:
        return user_dictionary[user][key]
    except:
        return ''

for key in preferred_keys:
    df[key] = df.people.apply(lambda x: extract_key(x, key))

df.head(6)
# Out:
#            people                   id                 name    screen_name  \
# 0       Joe Biden               939091            Joe Biden       JoeBiden
# 1       Elon Musk             44196397            Elon Musk       elonmusk
# 2  Greta Thunberg  1006419421244678144       Greta Thunberg  GretaThunberg
# 3   Angela Merkel            102550061  Plaid Angela Merkel   Plaid_Merkel
# 4      Xi Jinping  1483753685616365571   Xi Jinping 🇨🇳 ᶠᵃᵏᵉ   XoiXiJinping
# 5      Jeff Bezos             15506669           Jeff Bezos      JeffBezos
#
#          location followers_count friends_count
# 0  Washington, DC        36894438            47
# 1                       128325520           178
# 2         Sverige         5848016          2866
# 3    Berlin (not)           33770           308
# 4                           16086           185
# 5                         6118040           173

# %% [markdown]
# We can see that in some cases the account won't be properly found, like in Mr. Jinping case

# %%
# See None values, to check if the dataset is acceptable
df[df.id == '']
# Out:
#                    people id name screen_name location followers_count  \
# 241        Isabel Ge Mahe
# 580  Anastasija Sevastova
#
#     friends_count
# 241
# 580

# %%
df.drop([241, 580], inplace = True)

# %% [markdown]
# #### 3-  Now we have the Updated Dataframe

# %%
df.head(5)
# Out:
#            people                   id                 name    screen_name  \
# 0       Joe Biden               939091            Joe Biden       JoeBiden
# 1       Elon Musk             44196397            Elon Musk       elonmusk
# 2  Greta Thunberg  1006419421244678144       Greta Thunberg  GretaThunberg
# 3   Angela Merkel            102550061  Plaid Angela Merkel   Plaid_Merkel
# 4      Xi Jinping  1483753685616365571   Xi Jinping 🇨🇳 ᶠᵃᵏᵉ   XoiXiJinping
#
#          location followers_count friends_count
# 0  Washington, DC        36894438            47
# 1                       128325520           178
# 2         Sverige         5848016          2866
# 3    Berlin (not)           33770           308
# 4                           16086           185

# %%
df.to_csv('cleaned_people.csv', index=None, encoding='utf-8-sig')
